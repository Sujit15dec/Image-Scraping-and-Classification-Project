# %% [markdown]
#  ## Image Scraping and Classification

# %% [markdown]
# #### Image Scraping using Selenium

# %% [markdown]
# ## Importing Libraries

# %%
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.edge.service import Service

# %%
s = Service("msedgedriver.exe")

# %%
# Connecting to web driver
driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32/chromedriver.exe")
# Out:
# <ipython-input-11-911a5a5be2dc>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32/chromedriver.exe")

# %% [markdown]
# #### Scraping for Images of Saree

# %%
url='https://www.amazon.in/s?k=saree&ref=nb_sb_noss_2'
driver.get(url)

# %%
#getting the list of url of sarees
sarees=[]

for j in range(0,4):

    saree_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in saree_tag:
        dataset1=i.find_element_by_tag_name("img")
        saree=sarees.append(dataset1.get_attribute('src'))
    button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)
# Out:
# <ipython-input-42-156b2808b76c>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   saree_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
# <ipython-input-42-156b2808b76c>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")

# %%
len(sarees)
# Out:
# 251

# %%
for j in range(0,4):

    saree_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in saree_tag:
        dataset1=i.find_element_by_tag_name("img")
        saree=sarees.append(dataset1.get_attribute('src'))
    button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)
# Out:
# <ipython-input-44-e9584d0542c4>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   saree_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
# <ipython-input-44-e9584d0542c4>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-44-e9584d0542c4> in <module>
#       5         dataset1=i.find_element_by_tag_name("img")
#       6         saree=sarees.append(dataset1.get_attribute('src'))
# ----> 7     button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
#       8     driver.execute_script("arguments[0].click();", button)
#       9     time.sleep(5)
#
# ...

# %%
len(sarees)
# Out:
# 311

# %%
sarees
# Out:
# ['https://m.media-amazon.com/images/I/51Pg4-8zaVL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51PwfNKf9ML._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51pc-dbMi2L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/5191rORCZKL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91Utl0DCCBL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91zuOcKe0YL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71AZpUxG2zL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61ZqouWfK7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81AwqqkYTtL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81XKaSKvlyL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81nYCJ1wccL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81O-GyASO2L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81KP2h+tZPL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/811CuOoYBBL._AC_UL320_.jpg',
# ...

# %% [markdown]
# ##### Scraping Images for Trousers

# %%
url='https://www.amazon.in/s?k=trousers+for+men&crid=K3FCCGFZZAQ7&sprefix=trousers%2Caps%2C459&ref=nb_sb_ss_ts-doa-p_1_8'
driver.get(url)

# %%
#getting the list of url of sarees
trousers=[]

for j in range(0,4):

    trouser_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in trouser_tag:
        dataset1=i.find_element_by_tag_name("img")
        trouser=trousers.append(dataset1.get_attribute('src'))
    button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)
# Out:
# <ipython-input-19-a51ad8bf08d8>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   trouser_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
# <ipython-input-19-a51ad8bf08d8>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-19-a51ad8bf08d8> in <module>
#       8         dataset1=i.find_element_by_tag_name("img")
#       9         trouser=trousers.append(dataset1.get_attribute('src'))
# ---> 10     button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
#      11     driver.execute_script("arguments[0].click();", button)
#      12     time.sleep(5)
#
# ...

# %%
len(trousers)
# Out:
# 193

# %%
for j in range(0,4):

    trouser_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in trouser_tag:
        dataset1=i.find_element_by_tag_name("img")
        trouser=trousers.append(dataset1.get_attribute('src'))
    button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)
# Out:
# <ipython-input-21-6bc1860b7ab8>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   trouser_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
# <ipython-input-21-6bc1860b7ab8>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-21-6bc1860b7ab8> in <module>
#       5         dataset1=i.find_element_by_tag_name("img")
#       6         trouser=trousers.append(dataset1.get_attribute('src'))
# ----> 7     button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
#       8     driver.execute_script("arguments[0].click();", button)
#       9     time.sleep(5)
#
# ...

# %%
len(trousers)
# Out:
# 253

# %%
trousers
# Out:
# ['https://m.media-amazon.com/images/I/519ekwPMgeL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51CIu5DsoJL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/518L6nrYGEL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/31AEFFP7CQL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51hW9lqu+NL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/8129VYoq9bL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51H86JddBWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81d37fLAwUL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41os9xPpG-L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41MBTop9EqL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51t4YPuf4AL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/616XQ5WrPoL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61LJIhWgi-L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61ejunmHM5L._AC_UL320_.jpg',
# ...

# %% [markdown]
# #### Scraping Images for Jeans

# %%
url='https://www.amazon.in/s?k=jeans+mens&crid=3OMKVC4D45NVI&sprefix=jeans+m%2Caps%2C411&ref=nb_sb_ss_ts-doa-p_2_7'
driver.get(url)

# %%
#getting the list of url of sarees
jeans=[]

for j in range(0,4):

    jeans_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in jeans_tag:
        dataset1=i.find_element_by_tag_name("img")
        jean=jeans.append(dataset1.get_attribute('src'))
    button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)
# Out:
# <ipython-input-36-3fbb913642bf>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   jeans_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
# E:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:340: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# <ipython-input-36-3fbb913642bf>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")

# %%
len(jeans)
# Out:
# 240

# %%
for j in range(0,4):

    jeans_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in jeans_tag:
        dataset1=i.find_element_by_tag_name("img")
        jean=jeans.append(dataset1.get_attribute('src'))
    button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)
# Out:
# <ipython-input-38-244c58785251>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   jeans_tag=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']")
# <ipython-input-38-244c58785251>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")

# %%
len(jeans)
# Out:
# 360

# %%
jeans
# Out:
# ['https://m.media-amazon.com/images/I/81x3zEBlpwL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81a3uXKXKgL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71Gsi6GPPuL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/6158iPAJj4L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/8105LnXkrAL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81GoDjV63QS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61PHSRTqOML._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81bgzalgGsL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/718vYyIjaNL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81yJeCN3nvL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51g7zML7HUL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81Op5HUd+1L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81wAqvZ4HWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71NEBTzj8UL._AC_UL320_.jpg',
# ...

# %%
#making length of each lists equal
sarees=sarees[:431]
trousers=trousers[:431]
jeans=jeans[:431]

# %% [markdown]
# ##### We have 431 images of each type of clothes

# %%
# Creating Directories
import os
import shutil
import requests

def directory(dir):
    current_path=os.getcwd()
    new=os.path.join(current_path,dir)
    if not os.path.exists(new):
        os.makedirs(new)
        
directory('Sarees_Images')
directory('Trousers_Images')
directory('Jeans_Images')

# %%
# Dowloading images
for index, link in enumerate(sarees):
    print('Downloading {0} of 431 saree images'.format(index+1))
    response=requests.get(link)
    with open('Sarees_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(trousers):
    print('Downloading {0} of 431 trouser images'.format(index+1))
    response=requests.get(link)
    with open('Trousers_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(jeans):
    print('Downloading {0} of 431 jeans images'.format(index+1))
    response=requests.get(link)
    with open('Jeans_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %% [markdown]
# All images have been downloaded and saved
